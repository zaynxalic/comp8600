# %% [markdown]
# # Neural networks

# %% [markdown]
# ###### COMP4670/8600 - Statistical Machine Learning - Tutorial

# %% [markdown]
# Setting up the environment
#
# In this lab, we will train a neural network as a classifer.
#
# ### Assumed knowledge
# - Neural networks (lectures)
# - Classifiers (lab)
#
# ### After this lab, you should be comfortable with:
# - Implementing a neural network and a simple optimizer
# - Calculating back-propogation formulas

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as opt
# %matplotlib inline
# Out:
# In D:\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In D:\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In D:\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.

# %% [markdown]
# ## Load the data
#
# We will be working with a similar dataset to the one used in the Classification lab.
# This is a census-income dataset, which shows income levels for people in the 1994 US Census. We will predict whether a person has $\leq \$50000$ or $> \$50000$ income per year.
#
# Unlike in the Classification lab, this data is not linearly separable. That is, the linear classification techniques you learnt about in previous weeks are not effective on this data.
#
# The data is included with this notebook as `06-dataset.tsv`. Load the data into a NumPy array called `data` using numpy genfromtxt function.
# The column names are given in the variable `columns` below.

# %%
columns = ['income', 'age', 'education', 'private-work', 'married', 'capital-gain', 'capital-loss', 'hours-per-week']

# %%
data = np.genfromtxt("06-dataset.tsv")
data.shape
# Out:
# (32561, 8)

# %% [markdown]
# In this tutorial we will implement a neural network using only numpy functions.

# %% [markdown]
# ## Building blocks for a neural network
#
# Neural network libraries like PyTorch and TensorFlow seal different functionalities into different classes.
#
# First, implement the fully connected layer which does $\mathbf{y} = X\mathbf{w} + \mathbf{b}$.
# It is also called Linear layer in PyTorch or Dense layer in TensorFlow.

# %%
class FullyConnectedLayer():
    """
    This is a class skeleton provided.
    It should perform y = Xw + b and its correspongding gradient.
    If you never defined any classes in python before, you probably want to read other tutorials.
    """
    def __init__(self, in_features, out_features):
        """
        This is the init function where you have all the attributes needed defined.
        You don't have to modify any thing in this function but you should read it carefully.
        What each represents will be explained in the next few functions.
        """
        self.in_features = in_features
        self.out_features = out_features
        self.weight = np.zeros((in_features, out_features))
        self.bias = np.zeros((out_features, 1))
        self.g_weight = np.zeros((in_features, out_features))
        self.g_bias = np.zeros((out_features, 1))
        self.input = None

    def init_weights(self):
        """
        Currently, the weight and bias of this layer is initilized to zero, which is terrible.
        You want to re-initilize the weight with standard normal distribution 
        and the bias with uniform distribution defined on range 0 to 1.
        Or you can try different initilization methods.
        After you finish, comment out raise NotImplementedError.
        No return value is needed.
        """
        ################
        #YOUR CODE HERE#
        ################
        self.weight = np.random.normal(0, 0.1, (in_features, out_features))
        self.bias = np.random.uniform(0,1,(out_features, 1))
        
#         raise NotImplementedError

    def forward_pass(self, X):
        """
        Take the output of last layer as X and return the result.
        Don't forget to save the input X to self.input. You will need the input for gradient calculation.
        After you finish, comment out raise NotImplementedError.
        If you are new to python/numpy, you probably want to figure out what is broadcasting 
        (see http://cs231n.github.io/python-numpy-tutorial/#numpy-broadcasting).
        """
        ################
        #YOUR CODE HERE#
        ################
        self.input = X
        out = self.weight.T @ self.input + self.bias
        
        return out
        

    def backward_pass(self, g_next_layer):
        """
        g_next_layer is the gradient passed from next layer (the layer after current layer in forward pass).
        You need to calculate 3 things.
        First, the gradient with respect to bias, self.g_bias.
        Second, the gradient with respect to weights, self.g_weight.
        Third, the gradient with respect to last layer (the layer formed by the current weight and bias), g_last_layer.
        Save the gradient with respect to bias and the gradient with respect to weight.
        Return the gradient with respect to last layer.
        """
        
        ################
        #YOUR CODE HERE#
        ################
        self.g_weight = self.input @ g_next_layer
        self.g_bias = g_next_layer
        g_last_layer = self.weight @ g_next_layer

        return g_last_layer

    def update(self, learning_rate):
        """
        Update the weight and bias use the gradient that you just calculated.
        No return is needed.
        """
        
        ################
        #YOUR CODE HERE#
        ################
        self.weight -= learning_rate* self.g_weight
#         raise NotImplementedError
        return self.weight

# %% [markdown]
# ### Question 1:
#
# Why is initialising weights and biases to zero terrible?

# %% [markdown]
# ### <span style="color:blue">Answer</span>
# <i>--- replace this with your solution, add and remove code and markdown cells as appropriate ---</i>

# %% [markdown]
# Now let's implement sigmoid function and sigmoid layer.

# %%
def sigmoid(X):
    """
    Make sure that you function works with X being matrix.
    Use functions in numpy instead of functions in math.
    """
    ################
    #YOUR CODE HERE#
    ################

    return 1 / (1 + np.exp(-X))

# %%
class Sigmoid():
    def __init__(self):
        """
        This is the init function where you have all the attributes needed defined.
        You don't have to modify any thing in this function but you should read it carefully.
        """
        self.input = None

    def forward_pass(self, X):
        """
        Apply sigmoid function to input and save the input for later.
        """
        ################
        #YOUR CODE HERE#
        ################
        return sigmoid(self.input)

    def backward_pass(self, g_next_layer):
        """
        Calculate the gradient with respect to the input.
        g_next_layer is the gradient passed from next layer (the layer after current layer in forward pass).
        Return the gradient with respect to the output of the last layer.
        """
        g_last_layer = sigmoid(self.input) @ (np.eye(X.shape[0]) - sigmoid(self.input)) @ g_last_layer

        return g_last_layer

    def update(self, learning_rate):
        """
        There is no parameter to update for this layer, but we still define this function to maintain a uniform interface.
        """
        pass

# %% [markdown]
# ### Question 2:
#
# Why do we need the activation function to be non-linear?

# %% [markdown]
# ### <span style="color:blue">Answer</span>
# <i>--- replace this with your solution, add and remove code and markdown cells as appropriate ---</i>

# %% [markdown]
# Now let's implement binary cross entropy loss and yes, this is the same loss that you used in logistic regression.
# Binary cross entropy loss can only deal with two classes. For more than two classes you need softmax function and cross entropy, but let's not worry about that.

# %%
class BinaryCrossEntropyLoss():
    def __init__(self):
        """
        This is the init function where you have all the attributes needed defined.
        You don't have to modify any thing in this function but you should read it carefully.
        """
        self.input_y = None
        self.input_t = None
        self.input_N = None


    def forward_pass(self, y, t):
        """
        y: batch_size * 1  0 <= y <= 1, the predictions
        t: batch_size * 1 , the targets
        (make sure y and t have the same shape. (N,) and (N,1) are different!)
        
        Save the input y, t and batch size N and calculate the loss.
        Return the mean of the loss (a scalar).
        """
        
        ################
        #YOUR CODE HERE#
        ################
        
        raise NotImplementedError

        loss = None

        return loss
    
    def backward_pass(self, g_next_layer = 1):
        """
        Nomrally, loss layer is the last layer in a neural network. Thus, we set the g_next_layer to 1.
        Calculate the loss with respect to the input y.
        """
        ################
        #YOUR CODE HERE#
        ################
        
        raise NotImplementedError
        
        g_last_layer = None
        
        return g_last_layer

    def update(self, learning_rate):
        """
        There is no parameter to update for this layer, but we still define this function to maintain a uniform interface.
        """
        pass

# %% [markdown]
# Let's implement a neural network with one hidden layer to solve this classification problem.
#
# ### Question 3
# How many input units would there be? How many output units?

# %% [markdown]
# ### <span style="color:blue">Answer</span>
# <i>--- replace this with your solution, add and remove code and markdown cells as appropriate ---</i>

# %% [markdown]
# ## Put them together
#
# Put the bulding block together to form a neural network.

# %%
class Network():
    def __init__(self):
        """
        Since our simple nerual network acts sequentially, 
        we can put all layers in a list for convenient traversal
        Initialize all layers that you need (two fully connected layers, two sigmoid layers).
        Append them to the list in the correct order.
        Don't forget to initilize the weights for fully connected layers. Choose a sensible hidden layer size.
        """
        self.sequential = []
        
        ################
        #YOUR CODE HERE#
        ################
        
        raise NotImplementedError
        
    def forward_pass(self, X):

        for l in self.sequential:

            X = l.forward_pass(X)

        return X

    def backward_pass(self, grad):
        
        for l in reversed(self.sequential):

            grad = l.backward_pass(grad)
            

    def update(self, learning_rate):

        for l in self.sequential:

            l.update(learning_rate)

# %%
np.random.seed(1)
net = Network()
bce = BinaryCrossEntropyLoss()

# %% [markdown]
# You have already set up a neural network.
# In the backward_pass function of each layer, you calculated the gradient of the input and the gradient of the weight.
# Now, get a pen and a paper and try to replace g_next_layer with the backward_pass function of the next layer, all the way back to binary cross entropy loss. Don't change any code, just write it down.
#
# Compare the results with the text book.
# I hope you can see how this layer structure naturally implements the chain rule.

# %% [markdown]
# ## Training the neural network
#
# Split your data in half randomly, into a test set and a training set. Train the neural network on your training set. You may want to google train_test_split and accuracy_score of sklearn.
# If you get any memory error, make sure that all vectors in you calculate have shape (D, 1). (D, 1) and (D,) are different.
# Don't forget to normalize each feature to get mean 0 and variance 1.

# %%
""" Generate train and testing set """

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
data = np.genfromtxt("06-dataset.tsv")

y = data[:, 0]
X = data[:, 1:]

X_mean = X.mean(axis = 0)

X -= X_mean
X /= np.var(X, axis = 0)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.5)

training_epoch = 1000

train_acc_list = np.zeros(training_epoch)
train_loss_list = np.zeros(training_epoch)
test_acc_list = np.zeros(training_epoch)
test_loss_list = np.zeros(training_epoch)

training_epoch = 1000

train_acc_list = np.zeros(training_epoch)
train_loss_list = np.zeros(training_epoch)
test_acc_list = np.zeros(training_epoch)
test_loss_list = np.zeros(training_epoch)

# %%
for i in range(training_epoch):
    """
    This is the main training loop.
    You need to first run a forward pass, get the predicted probability, 
    put it into the loss function, calculate the loss and do a back pass.
    Then update the network.
    Calculate the test loss and the current accuracy on both the train and test sets.
    Save these to a list for plotting later.
    Experiment to find a good learning rate.
    """
    
    ################
    #YOUR CODE HERE#
    ################
    
    
    train_acc = 0    
    train_loss = 0

    grad = None

    train_acc_list[i] = train_acc
    train_loss_list[i] = train_loss

    """
    Calcualte the accuracy and loss on the testing set.
    """
    
    ################
    #YOUR CODE HERE#
    ################

    test_acc = 0
    test_loss = 0

    test_acc_list[i] = test_acc
    test_loss_list[i] = test_loss

    print("iteration %d: train_acc %f, train_loss %f, test_acc %f, test_loss %f" %(i+1, train_acc, train_loss, test_acc, test_loss))
# Out:
# iteration 1: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 2: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 3: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 4: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 5: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 6: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 7: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 8: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 9: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 10: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 11: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 12: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 13: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 14: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 15: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 16: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 17: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 18: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 19: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 20: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 21: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 22: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 23: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 24: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 25: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 26: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 27: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 28: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 29: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 30: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 31: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 32: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 33: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 34: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 35: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 36: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 37: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 38: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 39: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 40: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 41: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 42: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 43: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 44: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 45: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 46: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 47: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 48: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 49: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 50: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 51: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 52: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 53: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 54: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 55: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 56: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 57: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 58: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 59: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration
train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 465: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 466: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 467: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 468: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 469: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 470: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 471: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 472: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 473: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 474: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 475: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 476: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 477: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 478: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 479: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 480: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 481: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 482: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 483: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 484: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 485: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 486: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 487: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 488: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 489: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 490: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 491: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 492: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 493: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 494: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 495: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 496: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 497: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 498: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 499: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 500: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 501: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 502: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 503: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 504: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 505: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 506: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 507: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 508: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 509: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 510: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 511: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# ...
# iteration 831: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 832: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 833: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 834: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 835: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 836: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 837: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 838: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 839: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 840: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 841: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 842: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 843: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 844: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 845: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 846: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 847: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 848: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 849: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 850: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 851: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 852: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 853: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 854: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 855: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 856: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 857: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 858: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 859: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 860: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 861: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 862: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 863: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 864: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 865: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 866: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 867: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 868: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 869: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 870: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 871: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 872: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 873: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 874: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 875: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 876: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 877: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 878: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 879: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 880: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 881: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 882: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 883: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 884: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 885: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 886: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 887: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 888: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 889: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 890: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 891: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 892: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 893: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 894: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 895: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 896: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 897: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 898: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 899: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 900: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 901: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 902: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 903: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 904: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 905: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 906: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 907: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 908: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 909: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 910: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 911: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 912: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 913: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 914: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 915: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 916: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 917: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 918: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 919: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 920: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 921: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 922: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 923: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 924: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 925: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 926: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 927: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 928: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 929: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 930: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 931: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 932: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 933: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 934: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 935: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 936: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 937: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 938: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 939: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 940: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 941: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 942: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 943: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 944: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 945: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 946: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 947: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 948: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 949: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 950: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 951: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 952: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 953: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 954: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 955: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 956: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 957: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 958: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 959: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 960: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 961: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 962: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 963: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 964: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 965: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 966: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 967: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 968: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 969: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 970: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 971: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 972: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 973: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 974: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 975: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 976: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 977: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 978: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 979: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 980: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 981: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 982: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 983: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 984: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 985: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 986: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 987: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 988: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 989: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 990: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 991: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 992: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 993: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 994: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 995: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 996: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 997: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 998: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 999: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000
# iteration 1000: train_acc 0.000000, train_loss 0.000000, test_acc 0.000000, test_loss 0.000000

# %% [markdown]
# Plots of training accuracy curve against testing accuracy curve, and training loss curve against testing loss curve.

# %%
plt.title("Accuracy over epochs")
plt.plot(train_acc_list, label="Train")
plt.plot(test_acc_list, label="Test")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.title("Loss over epochs")
plt.plot(train_loss_list, label="Train")
plt.plot(test_loss_list, label="Test")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# Here is an super cool website:https://playground.tensorflow.org/.
# Have fun in there.

# %% [markdown]
# ## Textbook Questions (optional)
# These questions are hand picked to both be of reasonable difficulty and demonstrate what you are expected to be able to solve. The questions are labelled in Bishop as either $\star$, $\star\star$, or $\star\star\star$ to rate its difficulty.
#
# - **Question 5.1**: First derive the relationship between $\tanh(\alpha)$ and $\sigma(\alpha)$, then use Eq. 5.4 in Bishop to compare those two neural networks. The key point is having a clear definition of the notations you will use.
#
# - **Question 5.2**: Please figure out which parts of Gaussian distribution have parameters when taking the logarithm.
#
# - **Question 5.6**: Students should always know where the activation comes from and express the derivative of logistic sigmoid function in terms of the sigmoid function itself.
#
# - **Question 5.15**: Use the symmetry between backpropagation and forward propagation.
#
# - **Question 5.25**: Challenging but important question. Show you in which case gradient descent really work. First represent the current weight with its previous value and then use mathematical induction to prove Eq. 5.197.
#
# - **Question 5.27**: Follow what Section 5.5.5 did.
#
# - **Question 5.29**: Students should understand how to take the derivative of Gaussian distribution.
#
# - **Question 5.40**: Maping binary classfication domain to multiclass domain is a very practical demand.
